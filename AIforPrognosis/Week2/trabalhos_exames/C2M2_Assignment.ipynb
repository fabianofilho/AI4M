# %% [markdown]
# # Risk Models Using Tree-based Models
#
# Welcome to the second assignment of Course 2!

# %% [markdown]
# ## Outline
#
# - [1. Import Packages](#1)
# - [2. Load the Dataset](#2)
# - [3. Explore the Dataset](#3)
# - [4. Dealing with Missing Data](#4)
#     - [Exercise 1](#Ex-1)
# - [5. Decision Trees](#5)
#     - [Exercise 2](#Ex-2)
# - [6. Random Forests](#6)
#     - [Exercise 3](#Ex-3)
# - [7. Imputation](#7)
# - [8. Error Analysis](#8)
#     - [Exercise 4](#Ex-4)
# - [9. Imputation Approaches](#Ex-9)
#     - [Exercise 5](#Ex-5)
#     - [Exercise 6](#Ex-6)
# - [10. Comparison](#10)
# - [11. Explanations: SHAP](#)

# %% [markdown]
# In this assignment, you'll gain experience with tree based models by predicting the 10-year risk of death of individuals from the NHANES I epidemiology dataset (for a detailed description of this dataset you can check the [CDC Website](https://wwwn.cdc.gov/nchs/nhanes/nhefs/default.aspx/)). This is a challenging task and a great test bed for the machine learning methods we learned this week.
#
# As you go through the assignment, you'll learn about:
#
# - Dealing with Missing Data
#   - Complete Case Analysis.
#   - Imputation
# - Decision Trees
#   - Evaluation.
#   - Regularization.
# - Random Forests
#   - Hyperparameter Tuning.

# %% [markdown]
# <a name='1'></a>
# ## 1. Import Packages
#
# We'll first import all the common packages that we need for this assignment.
#
# - `shap` is a library that explains predictions made by machine learning models.
# - `sklearn` is one of the most popular machine learning libraries.
# - `itertools` allows us to conveniently manipulate iterable objects such as lists.
# - `pydotplus` is used together with `IPython.display.Image` to visualize graph structures such as decision trees.
# - `numpy` is a fundamental package for scientific computing in Python.
# - `pandas` is what we'll use to manipulate our data.
# - `seaborn` is a plotting library which has some convenient functions for visualizing missing data.
# - `matplotlib` is a plotting library.

# %%
import shap
import sklearn
import itertools
import pydotplus
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import Image 

from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer

# We'll also import some helper functions that will be useful later on.
from util import load_data, cindex

# %% [markdown]
# <a name='2'></a>
# ## 2. Load the Dataset

# %% [markdown]
# Run the next cell to load in the NHANES I epidemiology dataset. This dataset contains various features of hospital patients as well as their outcomes, i.e. whether or not they died within 10 years.

# %%
X_dev, X_test, y_dev, y_test = load_data(10)

# %% [markdown]
# The dataset has been split into a development set (or dev set), which we will use to develop our risk models, and a test set, which we will use to test our models.
#
# We further split the dev set into a training and validation set, respectively to train and tune our models, using a 75/25 split (note that we set a random state to make this split repeatable).

# %%
X_train, X_val, y_train, y_val = train_test_split(X_dev, y_dev, test_size=0.25, random_state=10)

# %% [markdown]
# <a name='3'></a>
# ## 3. Explore the Dataset
#
# The first step is to familiarize yourself with the data. Run the next cell to get the size of your training set and look at a small sample.

# %%
print("X_train shape: {}".format(X_train.shape))
X_train.head()
# Out:
# X_train shape: (5147, 18)
#        Age  Diastolic BP  Poverty index  Race  Red blood cells  \
# 1599  43.0          84.0          637.0   1.0             49.3
# 2794  72.0          96.0          154.0   2.0             43.4
# 1182  54.0          78.0          205.0   1.0             43.8
# 6915  59.0          90.0          417.0   1.0             43.4
# 500   34.0          80.0          385.0   1.0             77.7
#
#       Sedimentation rate  Serum Albumin  Serum Cholesterol  Serum Iron  \
# 1599                10.0            5.0              253.0       134.0
# 2794                23.0            4.3              265.0       106.0
# 1182                12.0            4.2              206.0       180.0
# 6915                 9.0            4.5              327.0       114.0
# 500                  9.0            4.1              197.0        64.0
#
#       Serum Magnesium  Serum Protein  Sex  Systolic BP   TIBC    TS  \
# 1599             1.59            7.7  1.0          NaN  490.0  27.3
# 2794             1.66            6.8  2.0        208.0  301.0  35.2
# 1182             1.67            6.6  2.0          NaN  363.0  49.6
# 6915             1.65            7.6  2.0          NaN  347.0  32.9
# 500              1.74            7.3  2.0          NaN  376.0  17.0
#
#       White blood cells        BMI  Pulse pressure
# 1599                9.1  25.803007            34.0
# 2794                6.0  33.394319           112.0
# 1182                5.9  20.278410            34.0
# 6915                6.1  32.917744            78.0
# 500                 8.2  30.743489            30.0

# %% [markdown]
# Our targets `y` will be whether or not the target died within 10 years. Run the next cell to see the target data series.

# %%
y_train.head(20)
# Out:
# 1599    False
# 2794     True
# 1182    False
# 6915    False
# 500     False
# 1188     True
# 9739    False
# 3266    False
# 6681    False
# 8822    False
# 5856     True
# 3415    False
# 9366    False
# 7975    False
# 1397    False
# 6809    False
# 9461    False
# 9374    False
# 1170     True
# 158     False
# Name: time, dtype: bool

# %% [markdown]
# Use the next cell to examine individual cases and familiarize yourself with the features.

# %%
i = 10
print(X_train.iloc[i,:])
print("\nDied within 10 years? {}".format(y_train.loc[y_train.index[i]]))
# Out:
# Age                    67.000000
# Diastolic BP           94.000000
# Poverty index         114.000000
# Race                    1.000000
# Red blood cells        43.800000
# Sedimentation rate     12.000000
# Serum Albumin           3.700000
# Serum Cholesterol     178.000000
# Serum Iron             73.000000
# Serum Magnesium         1.850000
# Serum Protein           7.000000
# Sex                     1.000000
# Systolic BP           140.000000
# TIBC                  311.000000
# TS                     23.500000
# White blood cells       4.300000
# BMI                    17.481227
# Pulse pressure         46.000000
# Name: 5856, dtype: float64
#
# Died within 10 years? True

# %% [markdown]
# <a name='4'></a>
# ## 4. Dealing with Missing Data
#
# Looking at our data in `X_train`, we see that some of the data is missing: some values in the output of the previous cell are marked as `NaN` ("not a number").
#
# Missing data is a common occurrence in data analysis, that can be due to a variety of reasons, such as measuring instrument malfunction, respondents not willing or not able to supply information, and errors in the data collection process.
#
# Let's examine the missing data pattern. `seaborn` is an alternative to `matplotlib` that has some convenient plotting functions for data analysis. We can use its `heatmap` function to easily visualize the missing data pattern.
#
# Run the cell below to plot the missing data:

# %%
sns.heatmap(X_train.isnull(), cbar=False)
plt.title("Training")
plt.show()

sns.heatmap(X_val.isnull(), cbar=False)
plt.title("Validation")
plt.show()

# %% [markdown]
# For each feature, represented as a column, values that are present are shown in black, and missing values are set in a light color.
#
# From this plot, we can see that many values are missing for systolic blood pressure (`Systolic BP`).

# %% [markdown]
# <a name='Ex-1'></a>
# ### Exercise 1
#
# In the cell below, write a function to compute the fraction of cases with missing data. This will help us decide how we handle this missing data in the future.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> The <code>pandas.DataFrame.isnull()</code> method is helpful in this case.</li>
#     <li> Use the <code>pandas.DataFrame.any()</code> method and set the <code>axis</code> parameter.</li>
#     <li> Divide the total number of rows with missing data by the total number of rows. Remember that in Python, <code>True</code> values are equal to 1.</li>
# </ul>
# </p>

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def fraction_rows_missing(df):
    '''
    Return percent of rows with any missing
    data in the dataframe. 
    
    Input:
        df (dataframe): a pandas dataframe with potentially missing data
    Output:
        frac_missing (float): fraction of rows with missing data
    '''
    ### START CODE HERE (REPLACE 'Pass' with your 'return' code) ###
    frac_missing = (df.isnull().sum()/df.any(axis=1).sum()).sum()
    return frac_missing
    ### END CODE HERE ###

# %% [markdown]
# Test your function by running the cell below.

# %%
df_test = pd.DataFrame({'a':[None, 1, 1, None], 'b':[1, None, 0, 1]})
print("Example dataframe:\n")
print(df_test)

print("\nComputed fraction missing: {}, expected: {}".format(fraction_rows_missing(df_test), 0.75))
print(f"Fraction of rows missing from X_train: {fraction_rows_missing(X_train):.3f}")
print(f"Fraction of rows missing from X_val: {fraction_rows_missing(X_val):.3f}")
print(f"Fraction of rows missing from X_test: {fraction_rows_missing(X_test):.3f}")
# Out:
# Example dataframe:
#
#      a    b
# 0  NaN  1.0
# 1  1.0  NaN
# 2  1.0  0.0
# 3  NaN  1.0
#
# Computed fraction missing: 0.75, expected: 0.75
# Fraction of rows missing from X_train: 0.699
# Fraction of rows missing from X_val: 0.704
# Fraction of rows missing from X_test: 0.000

# %% [markdown]
# We see that our train and validation sets have missing values, but luckily our test set has complete cases.

# %% [markdown]
# As a first pass, we will begin with a **complete case analysis**, dropping all of the rows with any missing data. Run the following cell to drop these rows from our train and validation sets.

# %%
X_train_dropped = X_train.dropna(axis='rows')
y_train_dropped = y_train.loc[X_train_dropped.index]
X_val_dropped = X_val.dropna(axis='rows')
y_val_dropped = y_val.loc[X_val_dropped.index]

# %% [markdown]
# <a name='5'></a>
# ## 5. Decision Trees
#
# Having just learned about decision trees, you choose to use a decision tree classifier. Use scikit-learn to build a decision tree for the hospital dataset using the train set.

# %%
dt = DecisionTreeClassifier(max_depth=None, random_state=10)
dt.fit(X_train_dropped, y_train_dropped)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=10, splitter='best')

# %% [markdown]
# Next we will evaluate our model. We'll use C-Index for evaluation.
#
# > Remember from lesson 4 of week 1 that the C-Index evaluates the ability of a model to differentiate between different classes, by quantifying how often, when considering all pairs of patients (A, B), the model says that patient A has a higher risk score than patient B when, in the observed data, patient A actually died and patient B actually lived. In our case, our model is a binary classifier, where each risk score is either 1 (the model predicts that the patient will die) or 0 (the patient will live).
# >
# > More formally, defining _permissible pairs_ of patients as pairs where the outcomes are different, _concordant pairs_ as permissible pairs where the patient that died had a higher risk score (i.e. our model predicted 1 for the patient that died and 0 for the one that lived), and _ties_ as permissible pairs where the risk scores were equal (i.e. our model predicted 1 for both patients or 0 for both patients), the C-Index is equal to:
# >
# > $$\text{C-Index} = \frac{\#\text{concordant pairs} + 0.5\times \#\text{ties}}{\#\text{permissible pairs}}$$
#
# Run the next cell to compute the C-Index on the train and validation set (we've given you an implementation this time).

# %%
y_train_preds = dt.predict_proba(X_train_dropped)[:, 1]
print(f"Train C-Index: {cindex(y_train_dropped.values, y_train_preds)}")


y_val_preds = dt.predict_proba(X_val_dropped)[:, 1]
print(f"Val C-Index: {cindex(y_val_dropped.values, y_val_preds)}")
# Out:
# Train C-Index: 1.0
# Val C-Index: 0.5629321808510638

# %% [markdown]
# Unfortunately your tree seems to be overfitting: it fits the training data so closely that it doesn't generalize well to other samples such as those from the validation set.
#
# > The training C-index comes out to 1.0 because, when initializing `DecisionTreeClasifier`, we have left `max_depth` and `min_samples_split` unspecified. The resulting decision tree will therefore keep splitting as far as it can, which pretty much guarantees a pure fit to the training data.
#
# To handle this, you can change some of the hyperparameters of our tree.

# %% [markdown]
# <a name='Ex-2'></a>
# ### Exercise 2
#
# Try and find a set of hyperparameters that improves the generalization to the validation set and recompute the C-index. If you do it right, you should get C-index above 0.6 for the validation set.
#
# You can refer to the documentation for the sklearn [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html).

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> Try limiting the depth of the tree (<code>'max_depth'</code>).</li>
# </ul>
# </p>

# %%
# Experiment with different hyperparameters for the DecisionTreeClassifier
# until you get a c-index above 0.6 for the validation set
dt_hyperparams = {
    # set your own hyperparameters below, such as 'min_samples_split': 1

    ### START CODE HERE ###
    'criterion':'entropy',
    'max_depth': 2,
    'min_samples_split': 2
    ### END CODE HERE ###
}

# %% [markdown]
# Run the next cell to fit and evaluate the regularized tree.

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
dt_reg = DecisionTreeClassifier(**dt_hyperparams, random_state=10)
dt_reg.fit(X_train_dropped, y_train_dropped)

y_train_preds = dt_reg.predict_proba(X_train_dropped)[:, 1]
y_val_preds = dt_reg.predict_proba(X_val_dropped)[:, 1]
print(f"Train C-Index: {cindex(y_train_dropped.values, y_train_preds)}")
print(f"Val C-Index (expected > 0.6): {cindex(y_val_dropped.values, y_val_preds)}")
# Out:
# Train C-Index: 0.6530603728090513
# Val C-Index (expected > 0.6): 0.6068650265957447

# %% [markdown]
# If you used a low `max_depth` you can print the entire tree. This allows for easy interpretability. Run the next cell to print the tree splits.

# %%
dot_data = StringIO()
export_graphviz(dt_reg, feature_names=X_train_dropped.columns, out_file=dot_data,  
                filled=True, rounded=True, proportion=True, special_characters=True,
                impurity=False, class_names=['neg', 'pos'], precision=2)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# > **Overfitting, underfitting, and the bias-variance tradeoff**
# >
# > If you tested several values of `max_depth`, you may have seen that a value of `3` gives training and validation C-Indices of about `0.689` and `0.630`, and that a `max_depth` of `2` gives better agreement with values of about `0.653` and `0.607`. In the latter case, we have further reduced overfitting, at the cost of a minor loss in predictive performance.
# >
# > Contrast this with a `max_depth` value of `1`, which results in C-Indices of about `0.597` for the training set and `0.598` for the validation set: we have eliminated overfitting but with a much stronger degradation of predictive performance.
# >
# > Lower predictive performance on the training and validation sets is indicative of the model _underfitting_ the data: it neither learns enough from the training data nor is able to generalize to unseen data (the validation data in our case).
# >
# > Finding a model that minimizes and acceptably balances underfitting and overfitting (e.g. selecting the model with a `max_depth` of `2` over the other values) is a common problem in machine learning that is known as the _bias-variance tradeoff_.

# %% [markdown]
# <a name='6'></a>
# ## 6. Random Forests
#
# No matter how you choose hyperparameters, a single decision tree is prone to overfitting. To solve this problem, you can try **random forests**, which combine predictions from many different trees to create a robust classifier.
#
# As before, we will use scikit-learn to build a random forest for the data. We will use the default hyperparameters.

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=10)
rf.fit(X_train_dropped, y_train_dropped)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=10, verbose=0,
#                        warm_start=False)

# %% [markdown]
# Now compute and report the C-Index for the random forest on the training and validation set.

# %%
y_train_rf_preds = rf.predict_proba(X_train_dropped)[:, 1]
print(f"Train C-Index: {cindex(y_train_dropped.values, y_train_rf_preds)}")

y_val_rf_preds = rf.predict_proba(X_val_dropped)[:, 1]
print(f"Val C-Index: {cindex(y_val_dropped.values, y_val_rf_preds)}")
# Out:
# Train C-Index: 1.0
# Val C-Index: 0.6660488696808511

# %% [markdown]
# Training a random forest with the default hyperparameters results in a model that has better predictive performance than individual decision trees as in the previous section, but this model is overfitting.
#
# We therefore need to tune (or optimize) the hyperparameters, to find a model that both has good predictive performance and minimizes overfitting.
#
# The hyperparameters we choose to adjust will be:
#
# - `n_estimators`: the number of trees used in the forest.
# - `max_depth`: the maximum depth of each tree.
# - `min_samples_leaf`: the minimum number (if `int`) or proportion (if `float`) of samples in a leaf.
#
# The approach we implement to tune the hyperparameters is known as a grid search:
#
# - We define a set of possible values for each of the target hyperparameters.
#
# - A model is trained and evaluated for every possible combination of hyperparameters.
#
# - The best performing set of hyperparameters is returned.
#
# The cell below implements a hyperparameter grid search, using the C-Index to evaluate each tested model.

# %%
def holdout_grid_search(clf, X_train_hp, y_train_hp, X_val_hp, y_val_hp, hyperparams, fixed_hyperparams={}):
    '''
    Conduct hyperparameter grid search on hold out validation set. Use holdout validation.
    Hyperparameters are input as a dictionary mapping each hyperparameter name to the
    range of values they should iterate over. Use the cindex function as your evaluation
    function.

    Input:
        clf: sklearn classifier
        X_train_hp (dataframe): dataframe for training set input variables
        y_train_hp (dataframe): dataframe for training set targets
        X_val_hp (dataframe): dataframe for validation set input variables
        y_val_hp (dataframe): dataframe for validation set targets
        hyperparams (dict): hyperparameter dictionary mapping hyperparameter
                            names to range of values for grid search
        fixed_hyperparams (dict): dictionary of fixed hyperparameters that
                                  are not included in the grid search

    Output:
        best_estimator (sklearn classifier): fitted sklearn classifier with best performance on
                                             validation set
        best_hyperparams (dict): hyperparameter dictionary mapping hyperparameter
                                 names to values in best_estimator
    '''
    best_estimator = None
    best_hyperparams = {}
    
    # hold best running score
    best_score = 0.0

    # get list of param values
    lists = hyperparams.values()
    
    # get all param combinations
    param_combinations = list(itertools.product(*lists))
    total_param_combinations = len(param_combinations)

    # iterate through param combinations
    for i, params in enumerate(param_combinations, 1):
        # fill param dict with params
        param_dict = {}
        for param_index, param_name in enumerate(hyperparams):
            param_dict[param_name] = params[param_index]
            
        # create estimator with specified params
        estimator = clf(**param_dict, **fixed_hyperparams)

        # fit estimator
        estimator.fit(X_train_hp, y_train_hp)
        
        # get predictions on validation set
        preds = estimator.predict_proba(X_val_hp)
        
        # compute cindex for predictions
        estimator_score = cindex(y_val_hp, preds[:,1])

        print(f'[{i}/{total_param_combinations}] {param_dict}')
        print(f'Val C-Index: {estimator_score}\n')

        # if new high score, update high score, best estimator
        # and best params 
        if estimator_score >= best_score:
                best_score = estimator_score
                best_estimator = estimator
                best_hyperparams = param_dict

    # add fixed hyperparamters to best combination of variable hyperparameters
    best_hyperparams.update(fixed_hyperparams)
    
    return best_estimator, best_hyperparams

# %% [markdown]
# <a name='Ex-3'></a>
# ### Exercise 3
#
# In the cell below, define the values you want to run the hyperparameter grid search on, and run the cell to find the best-performing set of hyperparameters.
#
# Your objective is to get a C-Index above `0.6` on both the train and validation set.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>n_estimators: try values greater than 100</li>
#     <li>max_depth: try values in the range 1 to 100</li>
#     <li>min_samples_leaf: try float values below .5 and/or int values greater than 2</li>
# </ul>
# </p>

# %%
def random_forest_grid_search(X_train_dropped, y_train_dropped, X_val_dropped, y_val_dropped):

    # Define ranges for the chosen random forest hyperparameters 
    hyperparams = {
        
        ### START CODE HERE (REPLACE array values with your code) ###

        # how many trees should be in the forest (int)
        'n_estimators': [10,50,100,150,200,300,400,500,750,100],

        # the maximum depth of trees in the forest (int)
        
        'max_depth': [1,5,10,20,50,75,100],
        
        # the minimum number of samples in a leaf as a fraction
        # of the total number of samples in the training set
        # Can be int (in which case that is the minimum number)
        # or float (in which case the minimum is that fraction of the
        # number of training set samples)
        'min_samples_leaf': [0.01,0.05,0.1,0.2,0.3,0.5],

        ### END CODE HERE ###
    }

    
    fixed_hyperparams = {
        'random_state': 10,
    }
    
    rf = RandomForestClassifier

    best_rf, best_hyperparams = holdout_grid_search(rf, X_train_dropped, y_train_dropped,
                                                    X_val_dropped, y_val_dropped, hyperparams,
                                                    fixed_hyperparams)

    print(f"Best hyperparameters:\n{best_hyperparams}")

    
    y_train_best = best_rf.predict_proba(X_train_dropped)[:, 1]
    print(f"Train C-Index: {cindex(y_train_dropped, y_train_best)}")

    y_val_best = best_rf.predict_proba(X_val_dropped)[:, 1]
    print(f"Val C-Index: {cindex(y_val_dropped, y_val_best)}")
    
    # add fixed hyperparamters to best combination of variable hyperparameters
    best_hyperparams.update(fixed_hyperparams)
    
    return best_rf, best_hyperparams

# %%
best_rf, best_hyperparams = random_forest_grid_search(X_train_dropped, y_train_dropped, X_val_dropped, y_val_dropped)
# Out:
# [1/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6113364361702127
#
# [2/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6410987367021277
#
# [3/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6409657579787233
#
# [4/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6383477393617021
#
# [5/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6175365691489362
#
# [6/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [7/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6478058510638298
#
# [8/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.662325465425532
#
# [9/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6589345079787234
#
# [10/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6433011968085106
#
# [11/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6175365691489362
#
# [12/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [13/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6705285904255319
#
# [14/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.665483710106383
#
# [15/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6589345079787234
#
# [16/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6433011968085106
#
# [17/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6175365691489362
#
# [18/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [19/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6740857712765957
#
# [20/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.665483710106383
#
# [21/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6589345079787234
#
# [22/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6433011968085106
#
# [23/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6175365691489362
#
# [24/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [25/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6740857712765957
#
# [26/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.665483710106383
#
# [27/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6589345079787234
#
# [28/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6433011968085106
#
# [29/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6175365691489362
#
# [30/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [31/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6740857712765957
#
# [32/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.665483710106383
#
# [33/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6589345079787234
#
# [34/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6433011968085106
#
# [35/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6175365691489362
#
# [36/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [37/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6740857712765957
#
# [38/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.665483710106383
#
# [39/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6589345079787234
#
# [40/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6433011968085106
#
# [41/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6175365691489362
#
# [42/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [43/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6581781914893617
#
# [44/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6585521941489362
#
# [45/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.658419215425532
#
# [46/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6652842420212766
#
# [47/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6631648936170212
#
# [48/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [49/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6732214095744681
#
# [50/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6757313829787234
#
# [51/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6675365691489362
#
# [52/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6638297872340425
#
# [53/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6631648936170212
#
# [54/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [55/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.678939494680851
#
# [56/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6755817819148936
#
# [57/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6675365691489362
#
# [58/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6638297872340425
#
# [59/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6631648936170212
#
# [60/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [61/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6791722074468085
#
# [62/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6755817819148936
#
# [63/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6675365691489362
#
# [64/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6638297872340425
#
# [65/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6631648936170212
#
# [66/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [67/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6791722074468085
#
# [68/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6755817819148936
#
# [69/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6675365691489362
#
# [70/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6638297872340425
#
# [71/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6631648936170212
#
# [72/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [73/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6791722074468085
#
# [74/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6755817819148936
#
# [75/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6675365691489362
#
# [76/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6638297872340425
#
# [77/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6631648936170212
#
# [78/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [79/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6791722074468085
#
# [80/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6755817819148936
#
# [81/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6675365691489362
#
# [82/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6638297872340425
#
# [83/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6631648936170212
#
# [84/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [85/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6569315159574468
#
# [86/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6583361037234042
#
# [87/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6570063164893617
#
# [88/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6635388962765958
#
# [89/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6527593085106383
#
# [90/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [91/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6756482712765958
#
# [92/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6780585106382979
#
# [93/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6689162234042553
#
# [94/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6620262632978723
#
# [95/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6527593085106383
#
# [96/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [97/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6805518617021277
#
# [98/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.677908909574468
#
# [99/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6689162234042553
#
# [100/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6620262632978723
#
# [101/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6527593085106383
#
# [102/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [103/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6806017287234043
#
# [104/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.677908909574468
#
# [105/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6689162234042553
#
# [106/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6620262632978723
#
# [107/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6527593085106383
#
# [108/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [109/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6806017287234043
#
# [110/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.677908909574468
#
# [111/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6689162234042553
#
# [112/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6620262632978723
#
# [113/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6527593085106383
#
# [114/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [115/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6806017287234043
#
# [116/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.677908909574468
#
# [117/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6689162234042553
#
# [118/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6620262632978723
#
# [119/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6527593085106383
#
# [120/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [121/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6806017287234043
#
# [122/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.677908909574468
#
# [123/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6689162234042553
#
# [124/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6620262632978723
#
# [125/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6527593085106383
#
# [126/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [127/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6580452127659574
#
# [128/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.659873670212766
#
# [129/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.658377659574468
#
# [130/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6692320478723405
#
# [131/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6553856382978723
#
# [132/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [133/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6769448138297872
#
# [134/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6790724734042554
#
# [135/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6692652925531914
#
# [136/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6671376329787234
#
# [137/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6553856382978723
#
# [138/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [139/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6756316489361702
#
# [140/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6796376329787234
#
# [141/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6692652925531914
#
# [142/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6671376329787234
#
# [143/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6553856382978723
#
# [144/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [145/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6746675531914894
#
# [146/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6796376329787234
#
# [147/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6692652925531914
#
# [148/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6671376329787234
#
# [149/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6553856382978723
#
# [150/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [151/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6746675531914894
#
# [152/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6796376329787234
#
# [153/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6692652925531914
#
# [154/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6671376329787234
#
# [155/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6553856382978723
#
# [156/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [157/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6746675531914894
#
# [158/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6796376329787234
#
# [159/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6692652925531914
#
# [160/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6671376329787234
#
# [161/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6553856382978723
#
# [162/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [163/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6746675531914894
#
# [164/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6796376329787234
#
# [165/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6692652925531914
#
# [166/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6671376329787234
#
# [167/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6553856382978723
#
# [168/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [169/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6647772606382979
#
# [170/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6677859042553191
#
# [171/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6643783244680851
#
# [172/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6750664893617021
#
# [173/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6601728723404255
#
# [174/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [175/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6762965425531915
#
# [176/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6826628989361702
#
# [177/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6718583776595745
#
# [178/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6743184840425532
#
# [179/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6601728723404255
#
# [180/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [181/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6766456117021277
#
# [182/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6827127659574468
#
# [183/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6718583776595745
#
# [184/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6743184840425532
#
# [185/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6601728723404255
#
# [186/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [187/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6744847074468086
#
# [188/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6827127659574468
#
# [189/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6718583776595745
#
# [190/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6743184840425532
#
# [191/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6601728723404255
#
# [192/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [193/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6744847074468086
#
# [194/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6827127659574468
#
# [195/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6718583776595745
#
# [196/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6743184840425532
#
# [197/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6601728723404255
#
# [198/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [199/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6744847074468086
#
# [200/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6827127659574468
#
# [201/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6718583776595745
#
# [202/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6743184840425532
#
# [203/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6601728723404255
#
# [204/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [205/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6744847074468086
#
# [206/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6827127659574468
#
# [207/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6718583776595745
#
# [208/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6743184840425532
#
# [209/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6601728723404255
#
# [210/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [211/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6679521276595745
#
# [212/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6694148936170212
#
# [213/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6667054521276595
#
# [214/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6727393617021277
#
# [215/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6646941489361702
#
# [216/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [217/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6782247340425532
#
# [218/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6832114361702127
#
# [219/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6724734042553191
#
# [220/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6728390957446808
#
# [221/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6646941489361702
#
# [222/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [223/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6784242021276595
#
# [224/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6823636968085106
#
# [225/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6724734042553191
#
# [226/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6728390957446808
#
# [227/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6646941489361702
#
# [228/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [229/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.675
#
# [230/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6823636968085106
#
# [231/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6724734042553191
#
# [232/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6728390957446808
#
# [233/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6646941489361702
#
# [234/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [235/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.675
#
# [236/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6823636968085106
#
# [237/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6724734042553191
#
# [238/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6728390957446808
#
# [239/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6646941489361702
#
# [240/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [241/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.675
#
# [242/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6823636968085106
#
# [243/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6724734042553191
#
# [244/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6728390957446808
#
# [245/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6646941489361702
#
# [246/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [247/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.675
#
# [248/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6823636968085106
#
# [249/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6724734042553191
#
# [250/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6728390957446808
#
# [251/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6646941489361702
#
# [252/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [253/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.669747340425532
#
# [254/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6711934840425532
#
# [255/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6680851063829787
#
# [256/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6728889627659574
#
# [257/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6629820478723404
#
# [258/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [259/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6775432180851064
#
# [260/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6813829787234043
#
# [261/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6741190159574468
#
# [262/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6712599734042554
#
# [263/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6629820478723404
#
# [264/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [265/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.675531914893617
#
# [266/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6816323138297873
#
# [267/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6741190159574468
#
# [268/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6712599734042554
#
# [269/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6629820478723404
#
# [270/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [271/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6725232712765957
#
# [272/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6816323138297873
#
# [273/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6741190159574468
#
# [274/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6712599734042554
#
# [275/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6629820478723404
#
# [276/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [277/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6725232712765957
#
# [278/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6816323138297873
#
# [279/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6741190159574468
#
# [280/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6712599734042554
#
# [281/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6629820478723404
#
# [282/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [283/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6725232712765957
#
# [284/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6816323138297873
#
# [285/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6741190159574468
#
# [286/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6712599734042554
#
# [287/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6629820478723404
#
# [288/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [289/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6725232712765957
#
# [290/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6816323138297873
#
# [291/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6741190159574468
#
# [292/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6712599734042554
#
# [293/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6629820478723404
#
# [294/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [295/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6700631648936171
#
# [296/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6731382978723405
#
# [297/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6702792553191489
#
# [298/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6751496010638298
#
# [299/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6619847074468085
#
# [300/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [301/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6763796542553191
#
# [302/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6812333776595745
#
# [303/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6754155585106383
#
# [304/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6732380319148936
#
# [305/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6619847074468085
#
# [306/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [307/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6769281914893617
#
# [308/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6817652925531915
#
# [309/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6754155585106383
#
# [310/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6732380319148936
#
# [311/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6619847074468085
#
# [312/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [313/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6745678191489362
#
# [314/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6817652925531915
#
# [315/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6754155585106383
#
# [316/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6732380319148936
#
# [317/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6619847074468085
#
# [318/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [319/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6745678191489362
#
# [320/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6817652925531915
#
# [321/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6754155585106383
#
# [322/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6732380319148936
#
# [323/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6619847074468085
#
# [324/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [325/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6745678191489362
#
# [326/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6817652925531915
#
# [327/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6754155585106383
#
# [328/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6732380319148936
#
# [329/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6619847074468085
#
# [330/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [331/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6745678191489362
#
# [332/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6817652925531915
#
# [333/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6754155585106383
#
# [334/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6732380319148936
#
# [335/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6619847074468085
#
# [336/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [337/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6694481382978723
#
# [338/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6727559840425532
#
# [339/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6711934840425532
#
# [340/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6766954787234043
#
# [341/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6623088430851064
#
# [342/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [343/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6758976063829787
#
# [344/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6797207446808511
#
# [345/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6773271276595745
#
# [346/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6741688829787233
#
# [347/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6623088430851064
#
# [348/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [349/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6773603723404256
#
# [350/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.679970079787234
#
# [351/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6773271276595745
#
# [352/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6741688829787233
#
# [353/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6623088430851064
#
# [354/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [355/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.675282579787234
#
# [356/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.679970079787234
#
# [357/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6773271276595745
#
# [358/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6741688829787233
#
# [359/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6623088430851064
#
# [360/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [361/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.675282579787234
#
# [362/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.679970079787234
#
# [363/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6773271276595745
#
# [364/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6741688829787233
#
# [365/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6623088430851064
#
# [366/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [367/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.675282579787234
#
# [368/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.679970079787234
#
# [369/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6773271276595745
#
# [370/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6741688829787233
#
# [371/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6623088430851064
#
# [372/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [373/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.675282579787234
#
# [374/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.679970079787234
#
# [375/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6773271276595745
#
# [376/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6741688829787233
#
# [377/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6623088430851064
#
# [378/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [379/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6569315159574468
#
# [380/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6583361037234042
#
# [381/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6570063164893617
#
# [382/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6635388962765958
#
# [383/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6527593085106383
#
# [384/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [385/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6756482712765958
#
# [386/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6780585106382979
#
# [387/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6689162234042553
#
# [388/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6620262632978723
#
# [389/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6527593085106383
#
# [390/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [391/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6805518617021277
#
# [392/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.677908909574468
#
# [393/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6689162234042553
#
# [394/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6620262632978723
#
# [395/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6527593085106383
#
# [396/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [397/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6806017287234043
#
# [398/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.677908909574468
#
# [399/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6689162234042553
#
# [400/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6620262632978723
#
# [401/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6527593085106383
#
# [402/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [403/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6806017287234043
#
# [404/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.677908909574468
#
# [405/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6689162234042553
#
# [406/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6620262632978723
#
# [407/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6527593085106383
#
# [408/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [409/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6806017287234043
#
# [410/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.677908909574468
#
# [411/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6689162234042553
#
# [412/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6620262632978723
#
# [413/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6527593085106383
#
# [414/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [415/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6806017287234043
#
# [416/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.677908909574468
#
# [417/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6689162234042553
#
# [418/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.6620262632978723
#
# [419/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6527593085106383
#
# [420/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# Best hyperparameters:
# {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.05, 'random_state': 10}
# Train C-Index: 0.7638783269961977
# Val C-Index: 0.6832114361702127

# %% [markdown]
# Finally, evaluate the model on the test set. This is a crucial step, as trying out many combinations of hyperparameters and evaluating them on the validation set could result in a model that ends up overfitting the validation set. We therefore need to check if the model performs well on unseen data, which is the role of the test set, which we have held out until now.

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
y_test_best = best_rf.predict_proba(X_test)[:, 1]

print(f"Test C-Index: {cindex(y_test.values, y_test_best)}")
# Out:
# Test C-Index: 0.7037909792835745

# %% [markdown]
# Your C-Index on the test set should be greater than `0.6`.

# %% [markdown]
# <a name='7'></a>
# ## 7. Imputation
#
# You've now built and optimized a random forest model on our data. However, there was still a drop in test C-Index. This might be because you threw away more than half of the data of our data because of missing values for systolic blood pressure. Instead, we can try filling in, or imputing, these values.
#
# First, let's explore to see if our data is missing at random or not. Let's plot histograms of the dropped rows against each of the covariates (aside from systolic blood pressure) to see if there is a trend. Compare these to the histograms of the feature in the entire dataset. Try to see if one of the covariates has a signficantly different distribution in the two subsets.

# %%
dropped_rows = X_train[X_train.isnull().any(axis=1)]

columns_except_Systolic_BP = [col for col in X_train.columns if col not in ['Systolic BP']]

for col in columns_except_Systolic_BP:
    sns.distplot(X_train.loc[:, col], norm_hist=True, kde=False, label='full data')
    sns.distplot(dropped_rows.loc[:, col], norm_hist=True, kde=False, label='without missing data')
    plt.legend()

    plt.show()

# %% [markdown]
# Most of the covariates are distributed similarly whether or not we have discarded rows with missing data. In other words missingness of the data is independent of these covariates.
#
# If this had been true across *all* covariates, then the data would have been said to be **missing completely at random (MCAR)**.
#
# But when considering the age covariate, we see that much more data tends to be missing for patients over 65. The reason could be that blood pressure was measured less frequently for old people to avoid placing additional burden on them.
#
# As missingness is related to one or more covariates, the missing data is said to be **missing at random (MAR)**.
#
# Based on the information we have, there is however no reason to believe that the _values_ of the missing data — or specifically the values of the missing systolic blood pressures — are related to the age of the patients.
# If this was the case, then this data would be said to be **missing not at random (MNAR)**.

# %% [markdown]
# <a name='8'></a>
# ## 8. Error Analysis
#
# <a name='Ex-4'></a>
# ### Exercise 4
# Using the information from the plots above, try to find a subgroup of the test data on which the model performs poorly. You should be able to easily find a subgroup of at least 250 cases on which the model has a C-Index of less than 0.69.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> Define a mask using a feature and a threshold, e.g. patients with a BMI below 20: <code>mask = X_test['BMI'] < 20 </code>. </li>
#     <li> Try to find a subgroup for which the model had little data.</li>
# </ul>
# </p>

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def bad_subset(forest, X_test, y_test):
    # define mask to select large subset with poor performance
    # currently mask defines the entire set
    
    ### START CODE HERE (REPLACE the code after 'mask =' with your code) ###
    mask = (X_test['Age'] < 60) & (X_test['Poverty index'] > 150) & (X_test['TS'] < 25)


         
    ### END CODE HERE ###

    X_subgroup = X_test[mask]
    y_subgroup = y_test[mask]
    subgroup_size = len(X_subgroup)

    y_subgroup_preds = forest.predict_proba(X_subgroup)[:, 1]
    performance = cindex(y_subgroup.values, y_subgroup_preds)
    
    return performance, subgroup_size

# %% [markdown]
# #### Test Your Work

# %%
performance, subgroup_size = bad_subset(best_rf, X_test, y_test)
print("Subgroup size should greater than 250, performance should be less than 0.69 ")
print(f"Subgroup size: {subgroup_size}, C-Index: {performance}")
# Out:
# Subgroup size should greater than 250, performance should be less than 0.69
# Subgroup size: 338, C-Index: 0.558008658008658

# %% [markdown]
# #### Expected Output
# Note, your actual output will vary depending on the hyper-parameters that you chose and the mask that you chose.
# - Make sure that the c-index is less than 0.69
# ```Python
# Subgroup size: 586, C-Index: 0.6275
# ```
#
# **Bonus**:
# - See if you can get a c-index as low as 0.53
# ```
# Subgroup size: 251, C-Index: 0.5331
# ```

# %% [markdown]
# <a name='9'></a>
# ## 9. Imputation Approaches
#
# Seeing that our data is not missing completely at random, we can handle the missing values by replacing them with substituted values based on the other values that we have. This is known as imputation.
#
# The first imputation strategy that we will use is **mean substitution**: we will replace the missing values for each feature with the mean of the available values. In the next cell, use the `SimpleImputer` from `sklearn` to use mean imputation for the missing values.

# %%
# Impute values using the mean
imputer = SimpleImputer(strategy='mean')
imputer.fit(X_train)
X_train_mean_imputed = pd.DataFrame(imputer.transform(X_train), columns=X_train.columns)
X_val_mean_imputed = pd.DataFrame(imputer.transform(X_val), columns=X_val.columns)

# %% [markdown]
# <a name='Ex-5'></a>
# ### Exercise 5
# Now perform a hyperparameter grid search to find the best-performing random forest model, and report results on the test set.
#
# Define the parameter ranges for the hyperparameter search in the next cell, and run the cell.
#
# #### Target performance
# Make your test c-index at least 0.74 or higher

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>n_estimators: try values greater than 100</li>
#     <li>max_depth: try values in the range 1 to 100</li>
#     <li>min_samples_leaf: try float values below .5 and/or int values greater than 2</li>
# </ul>
# </p>

# %%
# Define ranges for the random forest hyperparameter search 
hyperparams = {
    ### START CODE HERE (REPLACE array values with your code) ###

    # how many trees should be in the forest (int)
    'n_estimators': [10,50,100,150,200,300,400,500,750,100],


    # the maximum depth of trees in the forest (int)
    'max_depth': [1,5,10,20,50,75,100],

    # the minimum number of samples in a leaf as a fraction
    # of the total number of samples in the training set
    # Can be int (in which case that is the minimum number)
    # or float (in which case the minimum is that fraction of the
    # number of training set samples)
    'min_samples_leaf': [0.01,0.05,0.1,0.2,0.3,0.5],

    ### END CODE HERE ###
}

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
rf = RandomForestClassifier

rf_mean_imputed, best_hyperparams_mean_imputed = holdout_grid_search(rf, X_train_mean_imputed, y_train,
                                                                     X_val_mean_imputed, y_val,
                                                                     hyperparams, {'random_state': 10})

print("Performance for best hyperparameters:")

y_train_best = rf_mean_imputed.predict_proba(X_train_mean_imputed)[:, 1]
print(f"- Train C-Index: {cindex(y_train, y_train_best):.4f}")

y_val_best = rf_mean_imputed.predict_proba(X_val_mean_imputed)[:, 1]
print(f"- Val C-Index: {cindex(y_val, y_val_best):.4f}")

y_test_imp = rf_mean_imputed.predict_proba(X_test)[:, 1]
print(f"- Test C-Index: {cindex(y_test, y_test_imp):.4f}")
# Out:
# [1/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7024779660354498
#
# [2/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7024779660354498
#
# [3/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7062062062062062
#
# [4/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7092439511094609
#
# [5/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6881643031317651
#
# [6/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [7/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.741090331112023
#
# [8/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7238029786836728
#
# [9/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7213156757625304
#
# [10/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7081767233611052
#
# [11/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6881643031317651
#
# [12/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [13/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7505032147114576
#
# [14/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7307915290561712
#
# [15/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7213156757625304
#
# [16/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7081767233611052
#
# [17/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6881643031317651
#
# [18/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [19/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7457153465830255
#
# [20/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7307915290561712
#
# [21/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7213156757625304
#
# [22/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7081767233611052
#
# [23/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6881643031317651
#
# [24/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [25/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7457153465830255
#
# [26/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7307915290561712
#
# [27/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7213156757625304
#
# [28/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7081767233611052
#
# [29/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6881643031317651
#
# [30/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [31/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7457153465830255
#
# [32/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7307915290561712
#
# [33/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7213156757625304
#
# [34/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7081767233611052
#
# [35/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6881643031317651
#
# [36/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [37/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7457153465830255
#
# [38/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7307915290561712
#
# [39/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7213156757625304
#
# [40/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7081767233611052
#
# [41/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6881643031317651
#
# [42/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [43/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7190064250801778
#
# [44/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7189108848544857
#
# [45/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7226467248159222
#
# [46/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7184896393139343
#
# [47/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6908871995639891
#
# [48/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [49/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7483090465736887
#
# [50/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7395638588697157
#
# [51/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7339291569226494
#
# [52/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7199162285930182
#
# [53/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6908871995639891
#
# [54/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [55/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7561075174958038
#
# [56/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7405909162959055
#
# [57/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7339291569226494
#
# [58/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7199162285930182
#
# [59/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6908871995639891
#
# [60/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [61/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7509222888832433
#
# [62/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7405909162959055
#
# [63/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7339291569226494
#
# [64/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7199162285930182
#
# [65/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6908871995639891
#
# [66/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [67/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7509222888832433
#
# [68/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7405909162959055
#
# [69/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7339291569226494
#
# [70/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7199162285930182
#
# [71/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6908871995639891
#
# [72/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [73/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7509222888832433
#
# [74/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7405909162959055
#
# [75/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7339291569226494
#
# [76/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7199162285930182
#
# [77/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6908871995639891
#
# [78/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [79/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7509222888832433
#
# [80/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7405909162959055
#
# [81/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7339291569226494
#
# [82/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7199162285930182
#
# [83/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6908871995639891
#
# [84/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [85/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7152423573247868
#
# [86/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7147820271464523
#
# [87/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7171716184731369
#
# [88/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7135769174814728
#
# [89/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6878429405544373
#
# [90/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [91/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7484013297462321
#
# [92/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7385020595432743
#
# [93/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7316600765624627
#
# [94/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7152152152152152
#
# [95/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6878429405544373
#
# [96/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [97/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7547938393925379
#
# [98/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7403390375190809
#
# [99/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7316600765624627
#
# [100/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7152152152152152
#
# [101/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6878429405544373
#
# [102/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [103/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7528178938157246
#
# [104/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7403390375190809
#
# [105/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7316600765624627
#
# [106/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7152152152152152
#
# [107/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6878429405544373
#
# [108/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [109/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7528178938157246
#
# [110/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7403390375190809
#
# [111/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7316600765624627
#
# [112/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7152152152152152
#
# [113/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6878429405544373
#
# [114/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [115/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7528178938157246
#
# [116/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7403390375190809
#
# [117/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7316600765624627
#
# [118/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7152152152152152
#
# [119/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6878429405544373
#
# [120/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [121/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7528178938157246
#
# [122/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7403390375190809
#
# [123/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7316600765624627
#
# [124/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7152152152152152
#
# [125/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6878429405544373
#
# [126/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [127/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7206110665980514
#
# [128/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7189065421169543
#
# [129/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.718572151327032
#
# [130/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7166059769096645
#
# [131/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.692489669713097
#
# [132/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [133/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7486770935794796
#
# [134/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7382610376102784
#
# [135/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7327566177891558
#
# [136/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7171683614199883
#
# [137/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.692489669713097
#
# [138/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [139/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7526593838958264
#
# [140/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7389341619276544
#
# [141/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7327566177891558
#
# [142/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7171683614199883
#
# [143/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.692489669713097
#
# [144/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [145/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7526876116897809
#
# [146/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7389341619276544
#
# [147/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7327566177891558
#
# [148/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7171683614199883
#
# [149/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.692489669713097
#
# [150/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [151/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7526876116897809
#
# [152/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7389341619276544
#
# [153/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7327566177891558
#
# [154/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7171683614199883
#
# [155/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.692489669713097
#
# [156/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [157/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7526876116897809
#
# [158/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7389341619276544
#
# [159/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7327566177891558
#
# [160/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7171683614199883
#
# [161/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.692489669713097
#
# [162/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [163/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7526876116897809
#
# [164/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7389341619276544
#
# [165/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7327566177891558
#
# [166/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7171683614199883
#
# [167/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.692489669713097
#
# [168/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [169/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7217542922532076
#
# [170/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7196002944376046
#
# [171/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7200997092537222
#
# [172/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7164756947837209
#
# [173/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6927947470246819
#
# [174/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [175/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7492459921961007
#
# [176/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7381046990591459
#
# [177/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7324851966934396
#
# [178/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7173844126121783
#
# [179/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6927947470246819
#
# [180/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [181/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7531305709179896
#
# [182/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7387799947452875
#
# [183/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7324851966934396
#
# [184/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7173844126121783
#
# [185/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6927947470246819
#
# [186/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [187/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7544898477653358
#
# [188/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7387799947452875
#
# [189/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7324851966934396
#
# [190/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7173844126121783
#
# [191/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6927947470246819
#
# [192/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [193/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7544898477653358
#
# [194/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7387799947452875
#
# [195/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7324851966934396
#
# [196/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7173844126121783
#
# [197/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6927947470246819
#
# [198/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [199/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7544898477653358
#
# [200/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7387799947452875
#
# [201/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7324851966934396
#
# [202/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7173844126121783
#
# [203/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6927947470246819
#
# [204/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [205/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7544898477653358
#
# [206/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7387799947452875
#
# [207/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7324851966934396
#
# [208/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7173844126121783
#
# [209/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6927947470246819
#
# [210/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [211/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7223611898232288
#
# [212/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7206447228139202
#
# [213/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7217304071967846
#
# [214/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7165962057502188
#
# [215/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6914300417554213
#
# [216/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [217/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7501536243401753
#
# [218/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7390145025719863
#
# [219/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.732402684680342
#
# [220/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7166874032383794
#
# [221/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6914300417554213
#
# [222/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [223/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.754064259487253
#
# [224/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7394965464379781
#
# [225/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.732402684680342
#
# [226/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7166874032383794
#
# [227/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6914300417554213
#
# [228/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [229/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7548502949804469
#
# [230/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7394965464379781
#
# [231/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.732402684680342
#
# [232/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7166874032383794
#
# [233/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6914300417554213
#
# [234/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [235/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7548502949804469
#
# [236/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7394965464379781
#
# [237/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.732402684680342
#
# [238/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7166874032383794
#
# [239/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6914300417554213
#
# [240/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [241/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7548502949804469
#
# [242/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7394965464379781
#
# [243/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.732402684680342
#
# [244/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7166874032383794
#
# [245/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6914300417554213
#
# [246/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [247/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7548502949804469
#
# [248/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7394965464379781
#
# [249/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.732402684680342
#
# [250/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7166874032383794
#
# [251/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6914300417554213
#
# [252/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [253/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7215534406423777
#
# [254/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7192702463852139
#
# [255/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7216446381305384
#
# [256/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7167970573610487
#
# [257/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6918230595020183
#
# [258/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [259/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7495868970923201
#
# [260/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7384542894304282
#
# [261/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7323722855176218
#
# [262/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7177546309867351
#
# [263/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6918230595020183
#
# [264/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [265/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7536039293089185
#
# [266/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7388755349709797
#
# [267/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7323722855176218
#
# [268/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7177546309867351
#
# [269/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6918230595020183
#
# [270/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [271/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.754064259487253
#
# [272/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7388755349709797
#
# [273/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7323722855176218
#
# [274/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7177546309867351
#
# [275/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6918230595020183
#
# [276/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [277/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.754064259487253
#
# [278/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7388755349709797
#
# [279/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7323722855176218
#
# [280/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7177546309867351
#
# [281/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6918230595020183
#
# [282/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [283/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.754064259487253
#
# [284/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7388755349709797
#
# [285/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7323722855176218
#
# [286/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7177546309867351
#
# [287/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6918230595020183
#
# [288/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [289/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.754064259487253
#
# [290/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7388755349709797
#
# [291/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7323722855176218
#
# [292/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7177546309867351
#
# [293/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6918230595020183
#
# [294/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [295/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7218205190005624
#
# [296/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7194439558864721
#
# [297/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7230940267816623
#
# [298/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7177980583620497
#
# [299/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6930618253828666
#
# [300/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [301/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7499104310384137
#
# [302/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7383804628923935
#
# [303/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7324309124742964
#
# [304/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7176612621298087
#
# [305/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6930618253828666
#
# [306/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [307/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.753551816458541
#
# [308/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.738784337482819
#
# [309/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7324309124742964
#
# [310/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7176612621298087
#
# [311/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6930618253828666
#
# [312/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [313/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7537450682786908
#
# [314/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.738784337482819
#
# [315/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7324309124742964
#
# [316/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7176612621298087
#
# [317/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6930618253828666
#
# [318/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [319/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7537450682786908
#
# [320/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.738784337482819
#
# [321/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7324309124742964
#
# [322/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7176612621298087
#
# [323/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6930618253828666
#
# [324/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [325/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7537450682786908
#
# [326/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.738784337482819
#
# [327/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7324309124742964
#
# [328/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7176612621298087
#
# [329/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6930618253828666
#
# [330/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [331/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7537450682786908
#
# [332/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.738784337482819
#
# [333/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7324309124742964
#
# [334/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7176612621298087
#
# [335/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6930618253828666
#
# [336/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [337/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7207608910428867
#
# [338/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7185471805862261
#
# [339/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.723225394591989
#
# [340/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7179174836441647
#
# [341/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6925124690851372
#
# [342/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [343/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7491482806016428
#
# [344/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7375292863362277
#
# [345/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7322094328601921
#
# [346/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7179739392320738
#
# [347/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6925124690851372
#
# [348/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [349/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7527809805467073
#
# [350/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7386974827321899
#
# [351/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7322094328601921
#
# [352/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7179739392320738
#
# [353/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6925124690851372
#
# [354/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [355/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7535822156212612
#
# [356/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7386974827321899
#
# [357/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7322094328601921
#
# [358/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7179739392320738
#
# [359/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6925124690851372
#
# [360/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [361/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7535822156212612
#
# [362/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7386974827321899
#
# [363/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7322094328601921
#
# [364/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7179739392320738
#
# [365/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6925124690851372
#
# [366/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [367/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7535822156212612
#
# [368/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7386974827321899
#
# [369/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7322094328601921
#
# [370/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7179739392320738
#
# [371/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6925124690851372
#
# [372/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [373/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7535822156212612
#
# [374/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7386974827321899
#
# [375/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7322094328601921
#
# [376/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7179739392320738
#
# [377/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6925124690851372
#
# [378/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [379/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7152423573247868
#
# [380/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7147820271464523
#
# [381/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7171716184731369
#
# [382/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7135769174814728
#
# [383/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6878429405544373
#
# [384/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [385/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7484013297462321
#
# [386/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7385020595432743
#
# [387/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7316600765624627
#
# [388/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7152152152152152
#
# [389/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6878429405544373
#
# [390/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [391/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7547938393925379
#
# [392/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7403390375190809
#
# [393/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7316600765624627
#
# [394/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7152152152152152
#
# [395/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6878429405544373
#
# [396/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [397/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7528178938157246
#
# [398/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7403390375190809
#
# [399/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7316600765624627
#
# [400/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7152152152152152
#
# [401/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6878429405544373
#
# [402/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [403/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7528178938157246
#
# [404/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7403390375190809
#
# [405/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7316600765624627
#
# [406/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7152152152152152
#
# [407/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6878429405544373
#
# [408/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [409/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7528178938157246
#
# [410/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7403390375190809
#
# [411/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7316600765624627
#
# [412/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7152152152152152
#
# [413/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6878429405544373
#
# [414/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [415/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7528178938157246
#
# [416/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7403390375190809
#
# [417/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7316600765624627
#
# [418/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7152152152152152
#
# [419/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6878429405544373
#
# [420/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# Performance for best hyperparameters:
# - Train C-Index: 0.8172
# - Val C-Index: 0.7561
# - Test C-Index: 0.7781

# %% [markdown]
# #### Expected output
# Note, your actual c-index values will vary depending on the hyper-parameters that you choose.
# - Try to get a good Test c-index, similar these numbers below:
#
# ```Python
# Performance for best hyperparameters:
# - Train C-Index: 0.8109
# - Val C-Index: 0.7495
# - Test C-Index: 0.7805
# ```

# %% [markdown]
# Next, we will apply another imputation strategy, known as **multivariate feature imputation**, using scikit-learn's `IterativeImputer` class (see the [documentation](https://scikit-learn.org/stable/modules/impute.html#iterative-imputer)).
#
# With this strategy, for each feature that is missing values, a regression model is trained to predict observed values based on all of the other features, and the missing values are inferred using this model.
# As a single iteration across all features may not be enough to impute all missing values, several iterations may be performed, hence the name of the class `IterativeImputer`.
#
# In the next cell, use `IterativeImputer` to perform multivariate feature imputation.
#
# > Note that the first time the cell is run, `imputer.fit(X_train)` may fail with the message `LinAlgError: SVD did not converge`: simply re-run the cell.

# %%
# Impute using regression on other covariates
imputer = IterativeImputer(random_state=0, sample_posterior=False, max_iter=1, min_value=0)
imputer.fit(X_train)
X_train_imputed = pd.DataFrame(imputer.transform(X_train), columns=X_train.columns)
X_val_imputed = pd.DataFrame(imputer.transform(X_val), columns=X_val.columns)

# %% [markdown]
# <a name='Ex-6'></a>
# ### Exercise 6
#
# Perform a hyperparameter grid search to find the best-performing random forest model, and report results on the test set. Define the parameter ranges for the hyperparameter search in the next cell, and run the cell.
#
# #### Target performance
#
# Try to get a text c-index of at least 0.74 or higher.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>n_estimators: try values greater than 100</li>
#     <li>max_depth: try values in the range 1 to 100</li>
#     <li>min_samples_leaf: try float values below .5 and/or int values greater than 2</li>
# </ul>
# </p>

# %%
# Define ranges for the random forest hyperparameter search 
hyperparams = {
    ### START CODE HERE (REPLACE array values with your code) ###

    # how many trees should be in the forest (int)
    'n_estimators': [10,50,100,150,200,300,400,500,750,100],

    # the maximum depth of trees in the forest (int)
    'max_depth': [1,5,10,20,50,75,100],

    # the minimum number of samples in a leaf as a fraction
    # of the total number of samples in the training set
    # Can be int (in which case that is the minimum number)
    # or float (in which case the minimum is that fraction of the
    # number of training set samples)
    'min_samples_leaf': [0.01,0.05,0.1,0.2,0.3,0.5],

    ### END CODE HERE ###
}

# %%
# UNQ_C6 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
rf = RandomForestClassifier

rf_imputed, best_hyperparams_imputed = holdout_grid_search(rf, X_train_imputed, y_train,
                                                           X_val_imputed, y_val,
                                                           hyperparams, {'random_state': 10})

print("Performance for best hyperparameters:")

y_train_best = rf_imputed.predict_proba(X_train_imputed)[:, 1]
print(f"- Train C-Index: {cindex(y_train, y_train_best):.4f}")

y_val_best = rf_imputed.predict_proba(X_val_imputed)[:, 1]
print(f"- Val C-Index: {cindex(y_val, y_val_best):.4f}")

y_test_imp = rf_imputed.predict_proba(X_test)[:, 1]
print(f"- Test C-Index: {cindex(y_test, y_test_imp):.4f}")
# Out:
# [1/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.6980538021752772
#
# [2/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.6980538021752772
#
# [3/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.6980125461687284
#
# [4/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7042356890513073
#
# [5/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6881643031317651
#
# [6/420] {'n_estimators': 10, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [7/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7336164798203844
#
# [8/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7219399442826775
#
# [9/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7131697858378986
#
# [10/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7022771144246198
#
# [11/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6881643031317651
#
# [12/420] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [13/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.744182360234421
#
# [14/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.728830783060718
#
# [15/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7131697858378986
#
# [16/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7022771144246198
#
# [17/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6881643031317651
#
# [18/420] {'n_estimators': 10, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [19/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7512067381915538
#
# [20/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.728830783060718
#
# [21/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7131697858378986
#
# [22/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7022771144246198
#
# [23/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6881643031317651
#
# [24/420] {'n_estimators': 10, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [25/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7512067381915538
#
# [26/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.728830783060718
#
# [27/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7131697858378986
#
# [28/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7022771144246198
#
# [29/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6881643031317651
#
# [30/420] {'n_estimators': 10, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [31/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7512067381915538
#
# [32/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.728830783060718
#
# [33/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7131697858378986
#
# [34/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7022771144246198
#
# [35/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6881643031317651
#
# [36/420] {'n_estimators': 10, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [37/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7512067381915538
#
# [38/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.728830783060718
#
# [39/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7131697858378986
#
# [40/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7022771144246198
#
# [41/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6881643031317651
#
# [42/420] {'n_estimators': 10, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [43/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7174614962033617
#
# [44/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7180184522917712
#
# [45/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7174625818877446
#
# [46/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7133250387046483
#
# [47/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6908871995639891
#
# [48/420] {'n_estimators': 50, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [49/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7452571877734567
#
# [50/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7369842727760298
#
# [51/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7284594790017783
#
# [52/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7138168537300859
#
# [53/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6908871995639891
#
# [54/420] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [55/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7521816827673661
#
# [56/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.737023357413813
#
# [57/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7284594790017783
#
# [58/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7138168537300859
#
# [59/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6908871995639891
#
# [60/420] {'n_estimators': 50, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [61/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7532478248313389
#
# [62/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.737023357413813
#
# [63/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7284594790017783
#
# [64/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7138168537300859
#
# [65/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6908871995639891
#
# [66/420] {'n_estimators': 50, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [67/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7532478248313389
#
# [68/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.737023357413813
#
# [69/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7284594790017783
#
# [70/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7138168537300859
#
# [71/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6908871995639891
#
# [72/420] {'n_estimators': 50, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [73/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7532478248313389
#
# [74/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.737023357413813
#
# [75/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7284594790017783
#
# [76/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7138168537300859
#
# [77/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6908871995639891
#
# [78/420] {'n_estimators': 50, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [79/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7532478248313389
#
# [80/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.737023357413813
#
# [81/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7284594790017783
#
# [82/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7138168537300859
#
# [83/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6908871995639891
#
# [84/420] {'n_estimators': 50, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [85/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7134520637774434
#
# [86/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7135986311691301
#
# [87/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7120819300862685
#
# [88/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7094556595641194
#
# [89/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6872262718249703
#
# [90/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [91/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7439369955638936
#
# [92/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7353448893579045
#
# [93/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7250091740330352
#
# [94/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7105999709036586
#
# [95/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6872262718249703
#
# [96/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [97/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7502730496222904
#
# [98/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358334473301935
#
# [99/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7250091740330352
#
# [100/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7105999709036586
#
# [101/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6872262718249703
#
# [102/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [103/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7514890161310985
#
# [104/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358334473301935
#
# [105/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7250091740330352
#
# [106/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7105999709036586
#
# [107/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6872262718249703
#
# [108/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [109/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7514890161310985
#
# [110/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358334473301935
#
# [111/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7250091740330352
#
# [112/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7105999709036586
#
# [113/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6872262718249703
#
# [114/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [115/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7514890161310985
#
# [116/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358334473301935
#
# [117/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7250091740330352
#
# [118/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7105999709036586
#
# [119/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6872262718249703
#
# [120/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [121/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7514890161310985
#
# [122/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358334473301935
#
# [123/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7250091740330352
#
# [124/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7105999709036586
#
# [125/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6872262718249703
#
# [126/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [127/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.718092278829806
#
# [128/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.71657014932503
#
# [129/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7140752466132075
#
# [130/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7119006207943301
#
# [131/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6917524900171321
#
# [132/420] {'n_estimators': 150, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [133/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7433767824223355
#
# [134/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7353774598893905
#
# [135/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7257756672073374
#
# [136/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7128581944200165
#
# [137/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6917524900171321
#
# [138/420] {'n_estimators': 150, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [139/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7484295575401866
#
# [140/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7350756396309541
#
# [141/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7257756672073374
#
# [142/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7128581944200165
#
# [143/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6917524900171321
#
# [144/420] {'n_estimators': 150, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [145/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7504511018610802
#
# [146/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7350756396309541
#
# [147/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7257756672073374
#
# [148/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7128581944200165
#
# [149/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6917524900171321
#
# [150/420] {'n_estimators': 150, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [151/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7504511018610802
#
# [152/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7350756396309541
#
# [153/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7257756672073374
#
# [154/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7128581944200165
#
# [155/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6917524900171321
#
# [156/420] {'n_estimators': 150, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [157/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7504511018610802
#
# [158/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7350756396309541
#
# [159/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7257756672073374
#
# [160/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7128581944200165
#
# [161/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6917524900171321
#
# [162/420] {'n_estimators': 150, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [163/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7504511018610802
#
# [164/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7350756396309541
#
# [165/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7257756672073374
#
# [166/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7128581944200165
#
# [167/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6917524900171321
#
# [168/420] {'n_estimators': 150, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [169/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.720566553538354
#
# [170/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7187534606189704
#
# [171/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7172552161706175
#
# [172/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7129982477054061
#
# [173/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6916526070539085
#
# [174/420] {'n_estimators': 200, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [175/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.744471152280263
#
# [176/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358595037553822
#
# [177/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7260666306219452
#
# [178/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7136496583351247
#
# [179/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6916526070539085
#
# [180/420] {'n_estimators': 200, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [181/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7494370726474848
#
# [182/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358464755427879
#
# [183/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7260666306219452
#
# [184/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7136496583351247
#
# [185/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6916526070539085
#
# [186/420] {'n_estimators': 200, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [187/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7511546253411763
#
# [188/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358464755427879
#
# [189/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7260666306219452
#
# [190/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7136496583351247
#
# [191/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6916526070539085
#
# [192/420] {'n_estimators': 200, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [193/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7511546253411763
#
# [194/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358464755427879
#
# [195/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7260666306219452
#
# [196/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7136496583351247
#
# [197/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6916526070539085
#
# [198/420] {'n_estimators': 200, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [199/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7511546253411763
#
# [200/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358464755427879
#
# [201/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7260666306219452
#
# [202/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7136496583351247
#
# [203/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6916526070539085
#
# [204/420] {'n_estimators': 200, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [205/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7511546253411763
#
# [206/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358464755427879
#
# [207/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7260666306219452
#
# [208/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7136496583351247
#
# [209/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6916526070539085
#
# [210/420] {'n_estimators': 200, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [211/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7214937280013202
#
# [212/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.72018222126682
#
# [213/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7185200384766546
#
# [214/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7122469541124639
#
# [215/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6910652518027789
#
# [216/420] {'n_estimators': 300, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [217/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7460757937981365
#
# [218/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358877315493367
#
# [219/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7263814790929758
#
# [220/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7125618025834946
#
# [221/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6910652518027789
#
# [222/420] {'n_estimators': 300, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [223/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.751013486371404
#
# [224/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7361917231765388
#
# [225/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7263814790929758
#
# [226/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7125618025834946
#
# [227/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6910652518027789
#
# [228/420] {'n_estimators': 300, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [229/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7515780422504934
#
# [230/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7361917231765388
#
# [231/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7263814790929758
#
# [232/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7125618025834946
#
# [233/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6910652518027789
#
# [234/420] {'n_estimators': 300, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [235/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7515780422504934
#
# [236/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7361917231765388
#
# [237/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7263814790929758
#
# [238/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7125618025834946
#
# [239/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6910652518027789
#
# [240/420] {'n_estimators': 300, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [241/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7515780422504934
#
# [242/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7361917231765388
#
# [243/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7263814790929758
#
# [244/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7125618025834946
#
# [245/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6910652518027789
#
# [246/420] {'n_estimators': 300, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [247/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7515780422504934
#
# [248/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7361917231765388
#
# [249/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7263814790929758
#
# [250/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7125618025834946
#
# [251/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6910652518027789
#
# [252/420] {'n_estimators': 300, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [253/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7199943978685844
#
# [254/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7180184522917712
#
# [255/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7162053593723876
#
# [256/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7113110941744347
#
# [257/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6911260501282194
#
# [258/420] {'n_estimators': 400, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [259/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7459932817850389
#
# [260/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7360505842067664
#
# [261/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7258342941640121
#
# [262/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7119766187011306
#
# [263/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6911260501282194
#
# [264/420] {'n_estimators': 400, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [265/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7511567967099421
#
# [266/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.736085326107018
#
# [267/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7258342941640121
#
# [268/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7119766187011306
#
# [269/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6911260501282194
#
# [270/420] {'n_estimators': 400, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [271/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7522185960363834
#
# [272/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.736085326107018
#
# [273/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7258342941640121
#
# [274/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7119766187011306
#
# [275/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6911260501282194
#
# [276/420] {'n_estimators': 400, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [277/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7522185960363834
#
# [278/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.736085326107018
#
# [279/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7258342941640121
#
# [280/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7119766187011306
#
# [281/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6911260501282194
#
# [282/420] {'n_estimators': 400, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [283/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7522185960363834
#
# [284/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.736085326107018
#
# [285/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7258342941640121
#
# [286/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7119766187011306
#
# [287/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6911260501282194
#
# [288/420] {'n_estimators': 400, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [289/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7522185960363834
#
# [290/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.736085326107018
#
# [291/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7258342941640121
#
# [292/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7119766187011306
#
# [293/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6911260501282194
#
# [294/420] {'n_estimators': 400, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [295/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7201453079978025
#
# [296/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7179674251257765
#
# [297/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7164062109832174
#
# [298/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7112231537394227
#
# [299/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6921476791324948
#
# [300/420] {'n_estimators': 500, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [301/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7457414030082143
#
# [302/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7359615580873715
#
# [303/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7261773704289973
#
# [304/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7115141171540303
#
# [305/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6921476791324948
#
# [306/420] {'n_estimators': 500, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [307/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7510699419593129
#
# [308/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7361765235951787
#
# [309/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7261773704289973
#
# [310/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7115141171540303
#
# [311/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6921476791324948
#
# [312/420] {'n_estimators': 500, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [313/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7519732313658561
#
# [314/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7361765235951787
#
# [315/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7261773704289973
#
# [316/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7115141171540303
#
# [317/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6921476791324948
#
# [318/420] {'n_estimators': 500, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [319/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7519732313658561
#
# [320/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7361765235951787
#
# [321/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7261773704289973
#
# [322/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7115141171540303
#
# [323/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6921476791324948
#
# [324/420] {'n_estimators': 500, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [325/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7519732313658561
#
# [326/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7361765235951787
#
# [327/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7261773704289973
#
# [328/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7115141171540303
#
# [329/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6921476791324948
#
# [330/420] {'n_estimators': 500, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [331/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7519732313658561
#
# [332/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7361765235951787
#
# [333/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7261773704289973
#
# [334/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7115141171540303
#
# [335/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6921476791324948
#
# [336/420] {'n_estimators': 500, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [337/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7181194209393775
#
# [338/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7159849654426661
#
# [339/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7148276258905326
#
# [340/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7102254097915703
#
# [341/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6920239111128482
#
# [342/420] {'n_estimators': 750, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [343/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7457001470016654
#
# [344/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7347651338974549
#
# [345/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7254000204108664
#
# [346/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7106260273288473
#
# [347/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6920239111128482
#
# [348/420] {'n_estimators': 750, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [349/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7507789785447052
#
# [350/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7356488809851066
#
# [351/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7254000204108664
#
# [352/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7106260273288473
#
# [353/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6920239111128482
#
# [354/420] {'n_estimators': 750, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [355/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.751677925213717
#
# [356/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7356488809851066
#
# [357/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7254000204108664
#
# [358/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7106260273288473
#
# [359/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6920239111128482
#
# [360/420] {'n_estimators': 750, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [361/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.751677925213717
#
# [362/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7356488809851066
#
# [363/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7254000204108664
#
# [364/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7106260273288473
#
# [365/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6920239111128482
#
# [366/420] {'n_estimators': 750, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [367/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.751677925213717
#
# [368/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7356488809851066
#
# [369/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7254000204108664
#
# [370/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7106260273288473
#
# [371/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6920239111128482
#
# [372/420] {'n_estimators': 750, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [373/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.751677925213717
#
# [374/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7356488809851066
#
# [375/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7254000204108664
#
# [376/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7106260273288473
#
# [377/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6920239111128482
#
# [378/420] {'n_estimators': 750, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [379/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7134520637774434
#
# [380/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7135986311691301
#
# [381/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7120819300862685
#
# [382/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7094556595641194
#
# [383/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6872262718249703
#
# [384/420] {'n_estimators': 100, 'max_depth': 1, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [385/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7439369955638936
#
# [386/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7353448893579045
#
# [387/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7250091740330352
#
# [388/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7105999709036586
#
# [389/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6872262718249703
#
# [390/420] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [391/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7502730496222904
#
# [392/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358334473301935
#
# [393/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7250091740330352
#
# [394/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7105999709036586
#
# [395/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6872262718249703
#
# [396/420] {'n_estimators': 100, 'max_depth': 10, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [397/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7514890161310985
#
# [398/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358334473301935
#
# [399/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7250091740330352
#
# [400/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7105999709036586
#
# [401/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6872262718249703
#
# [402/420] {'n_estimators': 100, 'max_depth': 20, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [403/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7514890161310985
#
# [404/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358334473301935
#
# [405/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7250091740330352
#
# [406/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7105999709036586
#
# [407/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6872262718249703
#
# [408/420] {'n_estimators': 100, 'max_depth': 50, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [409/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7514890161310985
#
# [410/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358334473301935
#
# [411/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7250091740330352
#
# [412/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7105999709036586
#
# [413/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6872262718249703
#
# [414/420] {'n_estimators': 100, 'max_depth': 75, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# [415/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.01}
# Val C-Index: 0.7514890161310985
#
# [416/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.05}
# Val C-Index: 0.7358334473301935
#
# [417/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.1}
# Val C-Index: 0.7250091740330352
#
# [418/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.2}
# Val C-Index: 0.7105999709036586
#
# [419/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.3}
# Val C-Index: 0.6872262718249703
#
# [420/420] {'n_estimators': 100, 'max_depth': 100, 'min_samples_leaf': 0.5}
# Val C-Index: 0.5
#
# Performance for best hyperparameters:
# - Train C-Index: 0.8212
# - Val C-Index: 0.7532
# - Test C-Index: 0.7803

# %% [markdown]
# #### Expected Output
# Note, your actual output will vary depending on the hyper-parameters that you chose and the mask that you chose.
# ```Python
# Performance for best hyperparameters:
# - Train C-Index: 0.8131
# - Val C-Index: 0.7454
# - Test C-Index: 0.7797
# ```

# %% [markdown]
# <a name='10'></a>
# ## 10. Comparison
#
# For good measure, retest on the subgroup from before to see if your new models do better.

# %%
performance, subgroup_size = bad_subset(best_rf, X_test, y_test)
print(f"C-Index (no imputation): {performance}")

performance, subgroup_size = bad_subset(rf_mean_imputed, X_test, y_test)
print(f"C-Index (mean imputation): {performance}")

performance, subgroup_size = bad_subset(rf_imputed, X_test, y_test)
print(f"C-Index (multivariate feature imputation): {performance}")
# Out:
# C-Index (no imputation): 0.558008658008658
# C-Index (mean imputation): 0.45930735930735933
# C-Index (multivariate feature imputation): 0.4816017316017316

# %% [markdown]
# We should see that avoiding complete case analysis (i.e. analysis only on observations for which there is no missing data) allows our model to generalize a bit better. Remember to examine your missing cases to judge whether they are missing at random or not!

# %% [markdown]
# <a name='11'></a>
# ## 11. Explanations: SHAP
#
# Using a random forest has improved results, but we've lost some of the natural interpretability of trees. In this section we'll try to explain the predictions using slightly more sophisticated techniques.
#
# You choose to apply **SHAP (SHapley Additive exPlanations) **, a cutting edge method that explains predictions made by black-box machine learning models (i.e. models which are too complex to be understandable by humans as is).
#
# > Given a prediction made by a machine learning model, SHAP values explain the prediction by quantifying the additive importance of each feature to the prediction. SHAP values have their roots in cooperative game theory, where Shapley values are used to quantify the contribution of each player to the game.
# >
# > Although it is computationally expensive to compute SHAP values for general black-box models, in the case of trees and forests there exists a fast polynomial-time algorithm. For more details, see the [TreeShap paper](https://arxiv.org/pdf/1802.03888.pdf).
#
# We'll use the [shap library](https://github.com/slundberg/shap) to do this for our random forest model. Run the next cell to output the most at risk individuals in the test set according to our model.

# %%
X_test_risk = X_test.copy(deep=True)
X_test_risk.loc[:, 'risk'] = rf_imputed.predict_proba(X_test_risk)[:, 1]
X_test_risk = X_test_risk.sort_values(by='risk', ascending=False)
X_test_risk.head()
# Out:
#        Age  Diastolic BP  Poverty index  Race  Red blood cells  \
# 864   74.0         110.0          105.0   1.0             46.9
# 5493  67.0          80.0           30.0   1.0             77.7
# 8442  72.0          90.0          316.0   1.0             44.3
# 2044  74.0          80.0           83.0   1.0             47.6
# 2608  71.0          80.0          104.0   1.0             43.8
#
#       Sedimentation rate  Serum Albumin  Serum Cholesterol  Serum Iron  \
# 864                 45.0            4.4              233.0       102.0
# 5493                59.0            3.4              231.0        36.0
# 8442                10.0            3.9              175.0        69.0
# 2044                19.0            4.2              205.0        72.0
# 2608                23.0            4.0              201.0       119.0
#
#       Serum Magnesium  Serum Protein  Sex  Systolic BP   TIBC    TS  \
# 864              1.70            7.3  1.0        180.0  283.0  36.0
# 5493             1.40            6.3  1.0        170.0  202.0  17.8
# 8442             1.63            6.3  1.0        160.0  352.0  19.6
# 2044             1.71            6.9  1.0        180.0  310.0  23.2
# 2608             1.60            7.0  1.0        166.0  311.0  38.3
#
#       White blood cells        BMI  Pulse pressure      risk
# 864                 9.2  26.906341            70.0  0.523586
# 5493                8.4  17.029470            90.0  0.522611
# 8442                9.5  20.384065            70.0  0.517073
# 2044               10.8  20.900101           100.0  0.516780
# 2608                6.3  17.760766            86.0  0.508735

# %% [markdown]
# We can use SHAP values to try and understand the model output on specific individuals using force plots. Run the cell below to see a force plot on the riskiest individual.

# %%
explainer = shap.TreeExplainer(rf_imputed)
i = 0
shap_value = explainer.shap_values(X_test.loc[X_test_risk.index[i], :])[1]
shap.force_plot(explainer.expected_value[1], shap_value, feature_names=X_test.columns, matplotlib=True)

# %% [markdown]
# How to read this chart:
# - The red sections on the left are features which push the model towards the final prediction in the positive direction (i.e. a higher Age increases the predicted risk).
# - The blue sections on the right are features that push the model towards the final prediction in the negative direction (if an increase in a feature leads to a lower risk, it will be shown in blue).
# - Note that the exact output of your chart will differ depending on the hyper-parameters that you choose for your model.
#
# We can also use SHAP values to understand the model output in aggregate. Run the next cell to initialize the SHAP values (this may take a few minutes).

# %%
shap_values = shap.TreeExplainer(rf_imputed).shap_values(X_test)[1]

# %% [markdown]
# Run the next cell to see a summary plot of the SHAP values for each feature on each of the test examples. The colors indicate the value of the feature.

# %%
shap.summary_plot(shap_values, X_test)

# %% [markdown]
# Clearly we see that being a woman (`sex = 2.0`, as opposed to men for which `sex = 1.0`) has a negative SHAP value, meaning that it reduces the risk of dying within 10 years. High age and high systolic blood pressure have positive SHAP values, and are therefore related to increased mortality.
#
# You can see how features interact using dependence plots. These plot the SHAP value for a given feature for each data point, and color the points in using the value for another feature. This lets us begin to explain the variation in SHAP value for a single value of the main feature.
#
# Run the next cell to see the interaction between Age and Sex.

# %%
shap.dependence_plot('Age', shap_values, X_test, interaction_index='Sex')

# %% [markdown]
# We see that while Age > 50 is generally bad (positive SHAP value), being a woman generally reduces the impact of age. This makes sense since we know that women generally live longer than men.
#
# Let's now look at poverty index and age.

# %%
shap.dependence_plot('Poverty index', shap_values, X_test, interaction_index='Age')

# %% [markdown]
# We see that the impact of poverty index drops off quickly, and for higher income individuals age begins to explain much of variation in the impact of poverty index.
#
# Try some other pairs and see what other interesting relationships you can find!

# %% [markdown]
# # Congratulations!
#
# You have completed the second assignment in Course 2. Along the way you've learned to fit decision trees, random forests, and deal with missing data. Now you're ready to move on to week 3!
